# %%
# !pip install dnspython
# !pip install pymongo[srv] 
import pymongo
import re
import pandas as pd
import datetime as dt


client = pymongo.MongoClient("mongodb+srv://Aishwarya:Sathyaa4282@aishwarya.ejghein.mongodb.net/?retryWrites=true&w=majority")

db=client.library_management
st=db.student_login
iv=db.inventory
iu=db.issuedbook
#st is for Student details while registering the new account, iv - Inventory or avialable book in libarary,iu - to view the issued book

# %%
print("To create a new contact name                            enter---->1")  
print("To retrive (or) search a contact name or contact number enter---->2") 
print("To delete a contact number                              enter---->3") 
print("To update a contact                                     enter---->4")
print("To display contact                                      enter---->5")

def happy_home():
  press=input("Please enter here: ")
  if press=="1" or press=="2" or press=="3" or press=="4" or press=="5":
    if press=="1":
      new_contact()
    elif press=="2":
      search_contact()
    elif press=="3":
      delete_contact()
    elif press=="4":
      update_contact()
    elif press=="5":
      display_contact()
  else:
    print("Please enter the vaild number")
    happy_home()

def new_contact():
  d={
      "_id":contact_name(), 
      "phone_number":phone_number(),
      "mail": mail_id(),
      "place":place(),
      "pincode":pincode()
      }
  db.Directory.insert_one(d)
  print("Your contact details has been added successfully")
  print("THANK YOU")

def contact_name():
  i=0
  while(i==0):
    name=input("Enter your contact name: ")
    _name="[A-Z a-z \._-]{2,25}$"
    if db.Directory.find_one({'_id':{'$eq':name}}):
      print("The entered contact name already exists")
      print("Please enter a different name")
      i=0
    else:
      if re.match(_name,name):
        i=1
        if (contact_name is not None):
          return(name)
      else:
        i=0
        print("Please enter a valid name")

def phone_number():
  i=0
  while(i==0):
    phone_number1=input("Enter your phone number: ")
    _phone_number="[123456789][0-9]{9}$"
    if db.Directory.find_one({'phone_number': {'$eq':phone_number1}}):
      print("The entered phone number already exists")
      print("Please enter a different phone number")
      i=0
    else:
      if re.match(_phone_number,phone_number1) and len(phone_number1)==10:
        i=1
        if (phone_number is not None):
          return(phone_number1)
      else:
        i=0
        print("Please enter the valid phone number")

def mail_id():
  i=0
  while(i==0):
    mail=input("Enter your Email id    : ")
    _mail="^[a-z A-Z]+[\._]?[a-z A-Z 0-9 \._-]+[@]\w+[A-Z a-z]+[.][A-Z a-z]{2,3}$"
    if db.Directory.find_one({'mail': {'$eq':mail}}):
      print("The entered mail id already exists")
      print("Please enter a different mail id")
      i=0
    else:
      if re.match(_mail,mail):
        i=1
        if (mail_id is not None):
          return(mail)
      else:
        i=0
        print("Please enter the valid Email id")

def place():
  i=0
  while(i==0):
    department=input("Enter your place       : ")
    _department="[A-Z a-z \._-]{2,25}$"
    if re.match(_department,department):
      i=1
      if (place is not None):
          return(department)
      else:
        i=0
        print("Please enter the valid place")

def pincode():
  i=0
  while(i==0):
    pin=input("Enter 6 digit pincode  :")
    pin_="[0-9]{6}"
    if re.match(pin_,pin) and len(pin)==6:
      i=1
      if (pincode is not None):
        return(pin)
    else:
      i=0
      print("Please enter the correcrt pincode")

def search_contact():
  name1=input("Enter the name or mail ID or Mobile number:") 
  r={"$or":[{("_id"):(name1)},{("mail"):(name1)},{("phone_number"):(name1)}]}  
  for x in db.Directory.find(r):
    print("\n")
    print(x)
    print("THANK YOU")

def delete_contact():
  name1=input("Enter the name or mail ID or Mobile number: ") 
  r={"$or":[{("_id"):(name1)},{("mail"):(name1)},{("phone_number"):(name1)}]}  
  db.Directory.delete_one(r)
  print("Your contact details has been deleted successfully")


def update_name():
  i=0
  while(i==0):
    _name=input("Enter your contact name: ")
    if db.Directory.find_one({'_id':{'$eq':_name}}):
      i=1
      if (update_name is not None):
        return(_name)
    else:
      i=0
      print("The entered contact name does not match")
      print("Please enter a existing contact name")

def update_contact():
  print("To update your phone number            enter---->1")
  print("To update your mail id                 enter---->2")
  print("To update your place                   enter---->3")
  print("To update your pincode                 enter---->4")
  enter=input("Please enter here: ")
  if enter=="1" or enter=="2" or enter=="3" or enter=="4":
    if enter=="1":
      update_phone_number()
    elif enter=="2":
      update_mail_id()
    elif enter=="3":
      update_place()
    elif enter=="4":
      update_pincode()
  else:
    print("Please enter the vaild number")
    update_contact()

def update_phone_number():
  query=update_name()
  update=phone_number()
  query_1={'_id':query}
  query_2={'$set':{"phone_number":update}}
  db.Directory.update_one(query_1,query_2)
  print("Your contact details has been updated successfully")

def update_mail_id():
  query=update_name()
  update=mail_id()
  query_1={'_id':query}
  query_2={'$set':{"mail":update}}
  db.Directory.update_one(query_1,query_2)
  print("Your contact details has been updated successfully")

def update_place():
  query=update_name()
  update=input("<> Enter what you want to change: ")
  query_1={'_id':query}
  query_2={'$set':{"place":update}}
  db.Directory.update_one(query_1,query_2)
  print("Your contact details has been updated successfully")
def update_pincode():
  query=update_name()
  update=input("<> Enter what you want to change: ")
  query_1={'_id':query}
  query_2={'$set':{"pincode":update}}
  db.Directory.update_one(query_1,query_2)
  print("Your contact details has been updated successfull")


def display_contact():
  mylist=db.Directory.find({},{"_id":1,"phone_number":1,"mail":1,'place':1,'pincode':1}).sort("_id")
  mylist=pd.DataFrame(mylist)
  print(mylist)
  for i in mylist:
    mylist
  print("THANK YOU")

happy_home()
# Out:
# To create a new contact name                            enter---->1
# To retrive (or) search a contact name or contact number enter---->2
# To delete a contact number                              enter---->3
# To update a contact                                     enter---->4
# To display contact                                      enter---->5
# Please enter here: 1
# Enter your contact name: aish
# Enter your phone number: 78945612
# Please enter the valid phone number
# Enter your phone number: 9874154156
# Enter your Email id    : aish@gmail.com
# Enter your place       : chennai
# Enter 6 digit pincode  :600987
# Your contact details has been added successfully
# THANK YOU
